# %%
# !nvidia-smi
# Out:
# Sat Nov 11 18:48:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.2/78.2 GB disk)

# %%
api_key = "HDyk6S47gwPxPFOWRs6W"
rf = Roboflow(api_key=api_key)

# Replace with your project and dataset information
workspace_name = "hakimaharzallah-cl2yy"
project_name = "datset-fjfbf"
version_number = 2
download_path = "/content/drive/MyDrive/finals"

# Download the dataset
project = rf.workspace(workspace_name).project(project_name)
dataset = project.version(version_number).download("yolov8", download_path)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/finals in yolov8:: 100%|██████████| 1214/1214 [00:06<00:00, 182.57it/s]

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/finals
# Out:
# /content/drive/MyDrive/finals

# %%
# %cd /content/drive/MyDrive/finals

# !yolo task=detect mode=train model=yolov8l.pt data= data.yaml batch=64 epochs=75 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/finals
# ...
# 100% 83.7M/83.7M [00:00<00:00, 152MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
